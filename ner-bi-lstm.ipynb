# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from sklearn.metrics import f1_score
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['ner_dataset.csv', 'ner.csv']

# %%
dframe = pd.read_csv("../input/ner.csv", encoding = "ISO-8859-1", error_bad_lines=False)
# Out:
# b'Skipping line 281837: expected 25 fields, saw 34\n'

# %%
dframe.head()
# Out:
#    Unnamed: 0     lemma next-lemma ...        shape           word tag
# 0           0  thousand         of ...  capitalized      Thousands   O
# 1           1        of   demonstr ...    lowercase             of   O
# 2           2  demonstr       have ...    lowercase  demonstrators   O
# 3           3      have      march ...    lowercase           have   O
# 4           4     march    through ...    lowercase        marched   O
#
# [5 rows x 25 columns]

# %%
df1=dframe[['word','tag']]

# %%
data=[]
tag=[]
x=[]
y=[]
for k,v in zip(df1.word,df1.tag):
    
    if k==".":
        data.append(x)
        tag.append(y)
        x=[]
        y=[]
    else:
        x.append(k)
        y.append(v)

# %%
len(data[1])
# Out:
# 28

# %%
len(tag[1])
# Out:
# 28

# %%
len(data)
# Out:
# 47895

# %%
data=data[:20000]
tag=tag[:20000]

# %%
maxlen=max(map(len,data))

# %%
maxlen
# Out:
# 70

# %%
len(tag)
# Out:
# 20000

# %%
from collections import Counter,defaultdict

# %%
datadict=defaultdict(lambda:0)

# %%
special_tokens = ['<UNK>', '<PAD>']

# %%
uniq_data_words=set()
for x in data:
    uniq_data_words.update(set(x))

# %%
len(uniq_data_words)
# Out:
# 18518

# %%
words=special_tokens+list(x for x in uniq_data_words if x not in special_tokens)

# %%
uniq_tags=set()
for x in tag:
    uniq_tags.update(set(x))

# %%
uniq_tags
# Out:
# {'B-art',
#  'B-eve',
#  'B-geo',
#  'B-gpe',
#  'B-nat',
#  'B-org',
#  'B-per',
#  'B-tim',
#  'I-art',
#  'I-eve',
#  'I-geo',
#  'I-gpe',
#  'I-nat',
#  'I-org',
#  'I-per',
#  'I-tim',
#  'O'}

# %%
unique_tags=['<PAD>']+list(uniq_tags)

# %%
tok_2_indx=dict([(v,k) for k,v in enumerate(words)])

# %%
tok_2_indx
# Out:
# {'<UNK>': 0,
#  '<PAD>': 1,
#  'Atambayev': 2,
#  '1959': 3,
#  'beaches': 4,
#  'injure': 5,
#  'maneuvers': 6,
#  'Shujaat': 7,
#  'Caretaker': 8,
#  'affiliations': 9,
#  'manner': 10,
#  'disperse': 11,
#  'settlements': 12,
#  'XVI': 13,
#  'concert': 14,
#  'Shurpayev': 15,
#  'evading': 16,
#  'Chad': 17,
#  'drainage': 18,
#  'Abductees': 19,
#  'appalling': 20,
#  'unborn': 21,
#  'Hanssen-Bauer': 22,
#  'organizers': 23,
#  'Pyongyang': 24,
#  'crowds': 25,
#  'sedimentary': 26,
#  'Hsann': 27,
#  'plot': 28,
#  'sleeping': 29,
#  'climates': 30,
#  'teach': 31,
#  'equivalent': 32,
#  'speaks': 33,
#  'counts': 34,
#  'skirmish': 35,
#  'expert': 36,
#  'tracked': 37,
#  'Guerrero': 38,
#  'humiliating': 39,
#  'Geoscience': 40,
#  'Azeri': 41,
#  '2': 42,
#  'Jordanian': 43,
#  'malls': 44,
#  'residents': 45,
#  'triumphs': 46,
#  'one-time': 47,
#  'bird': 48,
#  '81': 49,
#  'Anbar': 50,
#  'celebrates': 51,
#  'Der': 52,
#  'Syrian-backed': 53,
#  'major': 54,
#  'COLUMBUS': 55,
#  'indicator': 56,
#  'stampede': 57,
#  'typically': 58,
#  'plots': 59,
#  'Crude': 60,
#  'supply': 61,
#  'owned': 62,
#  'foods': 63,
#  'Parasol': 64,
#  'inundated': 65,
#  'ways': 66,
#  'Although': 67,
#  'Arturo': 68,
#  'Omar': 69,
#  'cyanide-based': 70,
#  'Militants': 71,
#  'Bakili': 72,
#  'India': 73,
#  'bitterly': 74,
#  'Amerindian': 75,
#  'Jendayi': 76,
#  'Juventud': 77,
#  'assigned': 78,
#  'outbursts': 79,
#  'infrastructure': 80,
#  'collapse': 81,
#  'Syrians': 82,
#  'transition': 83,
#  'Bajaur': 84,
#  'fears': 85,
#  'Mladen': 86,
#  'waged': 87,
#  'Sirnak': 88,
#  'rubber': 89,
#  'thoughts': 90,
#  'Kunduz': 91,
#  'Roads': 92,
#  'sweltering': 93,
#  'trials': 94,
#  'Kids': 95,
#  'director': 96,
#  'meters': 97,
#  'scoundrel': 98,
#  'anti-retroviral': 99,
#  'Luzhkov': 100,
#  'heeds': 101,
#  '1002': 102,
#  'Feeling': 103,
#  'Sex': 104,
#  'runs': 105,
#  'Labado': 106,
#  '1,800': 107,
#  '7,000': 108,
#  'booster': 109,
#  'Independent': 110,
#  'Kjetil': 111,
#  'dollar': 112,
#  'Return': 113,
#  'Nhlabatsi': 114,
#  '4.1': 115,
#  'breast': 116,
#  'dwellers': 117,
#  'hope': 118,
#  'Sudeten': 119,
#  '14-year': 120,
#  'handovers': 121,
#  'fairly': 122,
#  'Hooper': 123,
#  'heavily-armed': 124,
#  'sermon': 125,
#  'gangs': 126,
#  'al-Arabiya': 127,
#  'measurable': 128,
#  'bishop': 129,
#  'Greek-led': 130,
#  'volcanic': 131,
#  'socializing': 132,
#  'solar': 133,
#  'Monte': 134,
#  'recovered': 135,
#  'liquid': 136,
#  'sabotage': 137,
#  'excessively': 138,
#  'westerners': 139,
#  'platforms': 140,
#  'museum': 141,
#  'statistics': 142,
#  'revolution': 143,
#  'non-violent': 144,
#  'Grenada': 145,
#  'Richter': 146,
#  'makers': 147,
#  'group': 148,
#  'aliens': 149,
#  'ravine': 150,
#  'delayed': 151,
#  '280': 152,
#  'Doha': 153,
#  'moans': 154,
#  'chairmanship': 155,
#  'retaliatory': 156,
#  'discussion': 157,
#  'Peru': 158,
#  'Lome': 159,
#  'ocean': 160,
#  '111': 161,
#  'failing': 162,
#  'officers': 163,
#  'qualifying': 164,
#  'stab': 165,
#  'trust': 166,
#  'overland': 167,
#  'recently-elected': 168,
#  'Foreign': 169,
#  'militant-related': 170,
#  'overcame': 171,
#  'campaigns': 172,
#  'homage': 173,
#  '39th': 174,
#  'kickbacks': 175,
#  'misdirected': 176,
#  '06-Apr': 177,
#  'leaves': 178,
#  'profited': 179,
#  'Palmer': 180,
#  'GUELLEH': 181,
#  'immigrants': 182,
#  'holy': 183,
#  'surrendering': 184,
#  'eat': 185,
#  '80-year-old': 186,
#  'pensioners': 187,
#  'decade': 188,
#  'rocket': 189,
#  'Dixie': 190,
#  'one-China': 191,
#  'echoing': 192,
#  'quarter-on-quarter': 193,
#  'goal': 194,
#  'semi': 195,
#  'city': 196,
#  'straight': 197,
#  'G': 198,
#  'treatment': 199,
#  'disgrace': 200,
#  'tomb': 201,
#  'Coast': 202,
#  'proved': 203,
#  'Karlovic': 204,
#  'Whittington': 205,
#  'contagious': 206,
#  'image': 207,
#  'Lieutenant-General': 208,
#  'wrangling': 209,
#  'Marcus': 210,
#  'outlandish': 211,
#  'trumped': 212,
#  'cigarettes': 213,
#  'Virunga': 214,
#  'adverse': 215,
#  'marine': 216,
#  'saved': 217,
#  'sirens': 218,
#  'reflects': 219,
#  'tunnels': 220,
#  'Livni': 221,
#  'function': 222,
#  'deal': 223,
#  'Yevpatoria': 224,
#  'prior': 225,
#  'crucial': 226,
#  'redraw': 227,
#  '9th': 228,
#  'current': 229,
#  'somewhere': 230,
#  'Guatemalans': 231,
#  'U.N.-backed': 232,
#  'anti-Syrian': 233,
#  'informed': 234,
#  'promise': 235,
#  'Selim': 236,
#  'trafficking': 237,
#  'analysts': 238,
#  'Huy': 239,
#  'Amerzeb': 240,
#  'vowing': 241,
#  'Bombings': 242,
#  'arm': 243,
#  'demolish': 244,
#  'consuming': 245,
#  '169': 246,
#  'security': 247,
#  'Akayev': 248,
#  'vastly': 249,
#  'Solidaria': 250,
#  'commanding': 251,
#  'Creole': 252,
#  'earners': 253,
#  'cheated': 254,
#  'Gunmen': 255,
#  'Dany': 256,
#  'Kwan': 257,
#  'candy': 258,
#  'pilotless': 259,
#  'predicted': 260,
#  'marchers': 261,
#  'Civil': 262,
#  'bowler': 263,
#  'Fallujans': 264,
#  'unlawfully': 265,
#  'Due': 266,
#  'folks': 267,
#  'unfurling': 268,
#  'avoidance': 269,
#  'Traditional': 270,
#  '65-year-old': 271,
#  'Gaston': 272,
#  'fishing': 273,
#  'sang': 274,
#  'falciparum': 275,
#  'Muzaffarabad': 276,
#  'rains': 277,
#  'Azeris': 278,
#  'appointee': 279,
#  'ca.': 280,
#  'rest': 281,
#  'territorial': 282,
#  'whale': 283,
#  'insolent': 284,
#  'Amir': 285,
#  'Taiwanese': 286,
#  'traces': 287,
#  'surges': 288,
#  'Hogg': 289,
#  'Distribution': 290,
#  'wants': 291,
#  'Al-Ghoul': 292,
#  'Philippines': 293,
#  'discipline': 294,
#  'abstaining': 295,
#  'passport': 296,
#  'Mladic': 297,
#  'subtracted': 298,
#  'dealers': 299,
#  'occupies': 300,
#  'Goods': 301,
#  'Fleihan': 302,
#  'confirming': 303,
#  'pure': 304,
#  'Plains': 305,
#  'head': 306,
#  'Israeli': 307,
#  'Channu': 308,
#  'investigation': 309,
#  'nullified': 310,
#  'gratitude': 311,
#  'Ayatollah': 312,
#  'work': 313,
#  'Singer': 314,
#  'Iyad': 315,
#  'blows': 316,
#  'fewer': 317,
#  '453': 318,
#  'Taliban-linked': 319,
#  'ruthless': 320,
#  'anti-corruption': 321,
#  'tours': 322,
#  'sort': 323,
#  'Transparency': 324,
#  'belonged': 325,
#  'raids': 326,
#  'peacekeeping': 327,
#  'casualties': 328,
#  'slap': 329,
#  'Agha': 330,
#  'Chernobyl': 331,
#  'Michigan': 332,
#  'headbands': 333,
#  'Tharanga': 334,
#  'victims': 335,
#  'suppressing': 336,
#  'Rauf': 337,
#  'hamper': 338,
#  'blame': 339,
#  'fitness': 340,
#  'placed': 341,
#  'soften': 342,
#  '28,000': 343,
#  'prey': 344,
#  'Breeze': 345,
#  'Six': 346,
#  'racism': 347,
#  'Square': 348,
#  'updates': 349,
#  'Acquisition': 350,
#  'rife': 351,
#  'missile': 352,
#  'preserving': 353,
#  'Dawei-Ye': 354,
#  'ongoing': 355,
#  'Shinzo': 356,
#  'stamp': 357,
#  'Hungary': 358,
#  'Ernest': 359,
#  'prefer': 360,
#  'Doe': 361,
#  'Yankee': 362,
#  'shared': 363,
#  'Chargers': 364,
#  'homeowner': 365,
#  'Kel': 366,
#  '2002': 367,
#  'Snagovo': 368,
#  'Rubina': 369,
#  'runways': 370,
#  'confirmed': 371,
#  'He': 372,
#  'flown': 373,
#  'resold': 374,
#  '9.00': 375,
#  'Madhoun': 376,
#  'Society': 377,
#  'illustrates': 378,
#  'disagrees': 379,
#  '120': 380,
#  'contract': 381,
#  'fast': 382,
#  'Nour': 383,
#  'controversy': 384,
#  'uprising': 385,
#  'economies': 386,
#  'Nuclear': 387,
#  'bastion': 388,
#  'Negotiations': 389,
#  '1,700': 390,
#  '380': 391,
#  'alpine': 392,
#  'wealthier': 393,
#  'paralysis': 394,
#  'minorities': 395,
#  'Islamists': 396,
#  'Kuchma': 397,
#  'Qazi': 398,
#  'Israeli-Lebanese': 399,
#  'wealthiest': 400,
#  'website': 401,
#  'number-two': 402,
#  'insurgency': 403,
#  'street-to-street': 404,
#  'losers': 405,
#  'stint': 406,
#  'tracker': 407,
#  'hometown': 408,
#  'unannounced': 409,
#  'significant': 410,
#  'fled': 411,
#  'demolition': 412,
#  'fold': 413,
#  'Prosecutor': 414,
#  'railroad': 415,
#  'shielded': 416,
#  'Arab': 417,
#  'Cholera': 418,
#  'electronically': 419,
#  'Amendment': 420,
#  'Chinese-sanctioned': 421,
#  'Groenefeld': 422,
#  'Dharmeratnam': 423,
#  'Pak': 424,
#  'clamp': 425,
#  'Bagram': 426,
#  '1,60,000': 427,
#  'Norwegian': 428,
#  'El-Arish': 429,
#  'abducting': 430,
#  'hurting': 431,
#  'fourth-seeded': 432,
#  'registering': 433,
#  'Warri': 434,
#  'endorsement': 435,
#  'Goats': 436,
#  'wings': 437,
#  'Burma-Thailand': 438,
#  'temporarily': 439,
#  'hosted': 440,
#  'Arlington': 441,
#  'Small': 442,
#  'morally': 443,
#  'Aye': 444,
#  'locales': 445,
#  'complicity': 446,
#  'Soldiers': 447,
#  'off-duty': 448,
#  'Delgado': 449,
#  'kilograms': 450,
#  'conduct': 451,
#  'taunting': 452,
#  'catheterization': 453,
#  'towering': 454,
#  'rode': 455,
#  'Kuwaiti': 456,
#  'Khaled': 457,
#  'Ohrid': 458,
#  'Serbia-Montenegro': 459,
#  'strife': 460,
#  'confidence-building': 461,
#  'cut': 462,
#  'Orenburg': 463,
#  'Hubei': 464,
#  'kidney': 465,
#  '225-seat': 466,
#  'hijacker': 467,
#  'E.U': 468,
#  'Sharm-el-Sheik': 469,
#  'culling': 470,
#  'native': 471,
#  'drink': 472,
#  'Izvestia': 473,
#  'multilaterals': 474,
#  'videotape': 475,
#  'News-agency': 476,
#  'stronghold': 477,
#  'character': 478,
#  'information': 479,
#  'checkpoints': 480,
#  'revealed': 481,
#  'October': 482,
#  'motive': 483,
#  'enhancing': 484,
#  'touches': 485,
#  'U.S.-India': 486,
#  'Nice': 487,
#  'clerics': 488,
#  'Abdul': 489,
#  'Latin': 490,
#  'Kaczynski': 491,
#  'facilitator': 492,
#  'northeastern': 493,
#  'mandate': 494,
#  'narrates': 495,
#  'Dom': 496,
#  'probably': 497,
#  'importance': 498,
#  'produced': 499,
#  'tried': 500,
#  'mid-November': 501,
#  'previously': 502,
#  'technical': 503,
#  'secular': 504,
#  'take': 505,
#  'incitement': 506,
#  'miracle': 507,
#  'rugged': 508,
#  'Valdas': 509,
#  'Bassel': 510,
#  'homelands': 511,
#  'boycott': 512,
#  'stalking': 513,
#  'Batad': 514,
#  'gems': 515,
#  'looser': 516,
#  '4,200': 517,
#  'annulled': 518,
#  'decent': 519,
#  're-establishing': 520,
#  'Racism': 521,
#  'Abu': 522,
#  '1,74,000': 523,
#  'overflowed': 524,
#  'Harlan': 525,
#  'if': 526,
#  'stocks': 527,
#  'acquisition': 528,
#  'Amid': 529,
#  'meeting': 530,
#  'observer': 531,
#  'injected': 532,
#  'disappointed': 533,
#  'May': 534,
#  'tolerant': 535,
#  'luxuries': 536,
#  'complete': 537,
#  'emergencies': 538,
#  'preserve': 539,
#  'shrines': 540,
#  'Shiloh': 541,
#  'comprehend': 542,
#  'slam': 543,
#  'civil': 544,
#  'clients': 545,
#  'investigating': 546,
#  'counted': 547,
#  'Ashkelon': 548,
#  'atrocities': 549,
#  'stockpiling': 550,
#  'organs': 551,
#  'American-Islamic': 552,
#  'withdrawal': 553,
#  'Alexis': 554,
#  'documents': 555,
#  'Bramble': 556,
#  'attackers': 557,
#  'touched': 558,
#  'travels': 559,
#  'slow': 560,
#  'unskilled': 561,
#  'Hashemi': 562,
#  'erosion': 563,
#  'runway': 564,
#  'final': 565,
#  'D-Ohio': 566,
#  'prayed': 567,
#  'vaccination': 568,
#  'Mussolini': 569,
#  'Alan': 570,
#  'Ulus': 571,
#  'ability': 572,
#  'dual': 573,
#  '61,000': 574,
#  'record-setting': 575,
#  'equalizer': 576,
#  'Carli': 577,
#  'drugs': 578,
#  'manifesto': 579,
#  'birthplace': 580,
#  'distinctive': 581,
#  'coming': 582,
#  'questionable': 583,
#  'Naval': 584,
#  'filed': 585,
#  'Border': 586,
#  'Gnassingbe': 587,
#  'provider': 588,
#  'Kharrazi': 589,
#  'hardship': 590,
#  'Rams': 591,
#  'ticket': 592,
#  'now-defunct': 593,
#  'Bernal': 594,
#  'Sequi': 595,
#  'Pushpa': 596,
#  'Huon': 597,
#  'Schroeder': 598,
#  'Statoil': 599,
#  'belong': 600,
#  'good': 601,
#  'course': 602,
#  'Kakooza': 603,
#  'Boldak': 604,
#  'EDT': 605,
#  'Teshiktosh': 606,
#  'soared': 607,
#  '23rd': 608,
#  'buyouts': 609,
#  'tolerated': 610,
#  'Albania': 611,
#  'supplement': 612,
#  'ACLU': 613,
#  'obvious': 614,
#  'US-Central': 615,
#  'tell': 616,
#  'jaws': 617,
#  'NLD': 618,
#  'nationwide': 619,
#  'Number': 620,
#  'then-President': 621,
#  'performing': 622,
#  'restored': 623,
#  'trigger': 624,
#  'consequences': 625,
#  'membership': 626,
#  'underlying': 627,
#  'economic': 628,
#  'Rafah': 629,
#  'amass': 630,
#  'Leasing': 631,
#  'Administrative': 632,
#  'cocked': 633,
#  'Why': 634,
#  'Financial': 635,
#  'Than': 636,
#  'conference': 637,
#  'fabricating': 638,
#  'steer': 639,
#  'Safina': 640,
#  'nullify': 641,
#  'SMART': 642,
#  'efforts': 643,
#  'conversion': 644,
#  'fright': 645,
#  'any': 646,
#  'smashing': 647,
#  'ago': 648,
#  'patrolling': 649,
#  'fused': 650,
#  'Sawyer': 651,
#  'search': 652,
#  'Falcons': 653,
#  'incited': 654,
#  'implications': 655,
#  'provide': 656,
#  'spills': 657,
#  'wars': 658,
#  'Condolezza': 659,
#  'electrocution': 660,
#  'Tetiana': 661,
#  'encouraging': 662,
#  'washed': 663,
#  'European-brokered': 664,
#  'Wam': 665,
#  'rand': 666,
#  'Twelve': 667,
#  'data': 668,
#  'marshy': 669,
#  'interests': 670,
#  'scrapped': 671,
#  'Fort': 672,
#  'exploration': 673,
#  'Harbhajan': 674,
#  'expires': 675,
#  'panels': 676,
#  'Katrina': 677,
#  'guarantee': 678,
#  'defenders': 679,
#  'Beijing-based': 680,
#  'Colom': 681,
#  'member-nations': 682,
#  'self-governing': 683,
#  'disciplined': 684,
#  'Dabas': 685,
#  'Conoco': 686,
#  'cane': 687,
#  'Revolution': 688,
#  'Croat': 689,
#  '45': 690,
#  'Duke': 691,
#  'will': 692,
#  'working': 693,
#  'residing': 694,
#  'Accidents': 695,
#  '1839': 696,
#  'Kamdesh': 697,
#  'martial': 698,
#  'national-level': 699,
#  'billionaire': 700,
#  'Joseph': 701,
#  'gaps': 702,
#  'cancellation': 703,
#  'future': 704,
#  'tourism': 705,
#  'covertly': 706,
#  'Eelam': 707,
#  'cheeks': 708,
#  'Thirty-one-year-old': 709,
#  'Mahsouli': 710,
#  'price': 711,
#  'wedding': 712,
#  'Macedonian-American': 713,
#  'threats': 714,
#  'Alexandria': 715,
#  'BBC': 716,
#  'occupied': 717,
#  'tiny': 718,
#  'Fox': 719,
#  'Kurdistan': 720,
#  'abuses': 721,
#  '1,170': 722,
#  'Vines': 723,
#  'modestly': 724,
#  'Noor': 725,
#  'directive': 726,
#  'non-governmental': 727,
#  'meant': 728,
#  'Sarah': 729,
#  'band': 730,
#  'Maddalena': 731,
#  'headline': 732,
#  'Smaller': 733,
#  'Mahmud': 734,
#  'peg': 735,
#  'Beatrice': 736,
#  'Palma': 737,
#  'Sangin': 738,
#  'peninsula': 739,
#  'sheriff': 740,
#  'filmmaker': 741,
#  '1498': 742,
#  'rates': 743,
#  're-vote': 744,
#  'state-funded': 745,
#  'co-educational': 746,
#  'Caribbean': 747,
#  'French-Colombian': 748,
#  '1.1': 749,
#  'arisen': 750,
#  'human': 751,
#  'ships': 752,
#  'Brazil': 753,
#  'Hiroyuki': 754,
#  'phoenixes': 755,
#  '125': 756,
#  'Gurage': 757,
#  'must': 758,
#  'rendered': 759,
#  'truncated': 760,
#  'accession': 761,
#  'Enlargement': 762,
#  'U.N.': 763,
#  'Qais': 764,
#  'observing': 765,
#  'Velvet': 766,
#  'consented': 767,
#  'Zaken': 768,
#  'Citroën': 769,
#  'Defectors': 770,
#  'toys': 771,
#  'escorted': 772,
#  'Haradinaj': 773,
#  'red-shirts': 774,
#  'Separately': 775,
#  '39': 776,
#  '1,55,000': 777,
#  'leaders': 778,
#  'Ritchie': 779,
#  'Law': 780,
#  'ingratitude': 781,
#  'British-based': 782,
#  'Cavaco': 783,
#  'praying': 784,
#  'privatized': 785,
#  'basket': 786,
#  'apartment': 787,
#  'lawyer-activist': 788,
#  'parents': 789,
#  'Hausa': 790,
#  'universally': 791,
#  'Silvan': 792,
#  'Seville': 793,
#  'win': 794,
#  'Center': 795,
#  'Pascal': 796,
#  'innocence': 797,
#  'paintings': 798,
#  'consisting': 799,
#  'nationalists': 800,
#  'riding': 801,
#  'Kathmandu': 802,
#  'Himalayas': 803,
#  'Jehan': 804,
#  'voices': 805,
#  'total': 806,
#  'economist': 807,
#  'trial': 808,
#  'decreed': 809,
#  'found': 810,
#  'slowed': 811,
#  'hanged': 812,
#  '\x97': 813,
#  'plantation': 814,
#  'apparel': 815,
#  'Shanksville': 816,
#  'Chernikhov': 817,
#  'shake': 818,
#  'five-decade': 819,
#  'neighborhood': 820,
#  'Oxford': 821,
#  'causing': 822,
#  'characterized': 823,
#  'reconciliation': 824,
#  'Nicaragua': 825,
#  'Texmelucan': 826,
#  'Bajur': 827,
#  'patent': 828,
#  'star-studded': 829,
#  'consultation': 830,
#  'Doctors': 831,
#  'pictures': 832,
#  'al-Hariri': 833,
#  'disparity': 834,
#  'proposal': 835,
#  'rocket-propelled': 836,
#  'Investors': 837,
#  'Hamza': 838,
#  'foliage': 839,
#  'Guadalupe': 840,
#  'firearms': 841,
#  'Disasters': 842,
#  'poisoning': 843,
#  'largely': 844,
#  'legalizing': 845,
#  'moments': 846,
#  'trillions': 847,
#  'idleness': 848,
#  'ranges': 849,
#  'rigorous': 850,
#  'radical': 851,
#  'matters': 852,
#  'ribbon': 853,
#  'test-fired': 854,
#  'factories': 855,
#  'seem': 856,
#  'Jawed': 857,
#  'slightly': 858,
#  'Trade': 859,
#  'maltreated': 860,
#  'non-Jews': 861,
#  'Prague': 862,
#  'fertile': 863,
#  'Lage': 864,
#  'Providencia': 865,
#  'indulging': 866,
#  'Peineta': 867,
#  'kilted': 868,
#  'interpreting': 869,
#  'costly': 870,
#  'Namibia': 871,
#  'large-scale': 872,
#  'Kasuri': 873,
#  'Burton': 874,
#  'spying': 875,
#  'Chung': 876,
#  'Hit': 877,
#  'abductors': 878,
#  'regain': 879,
#  '[': 880,
#  '300': 881,
#  'retribution': 882,
#  'Khalis': 883,
#  'dividend': 884,
#  'laughing': 885,
#  'Naked': 886,
#  'Team': 887,
#  'Substantial': 888,
#  'create': 889,
#  'exhumed': 890,
#  'testified': 891,
#  'orderly': 892,
#  'U.S.-educated': 893,
#  'Gbagbo': 894,
#  'addressed': 895,
#  'Organization': 896,
#  'Ismail': 897,
#  'unreliable': 898,
#  'Facility': 899,
#  'containing': 900,
#  'hitch': 901,
#  'Roosevelt': 902,
#  'Pelosi': 903,
#  'auctioneers': 904,
#  'Rohani': 905,
#  'sealing': 906,
#  'Cowell': 907,
#  'Reich': 908,
#  'date': 909,
#  'Zapatista': 910,
#  'populous': 911,
#  'grids': 912,
#  'Adnan': 913,
#  '\x96': 914,
#  'kinds': 915,
#  'sanction': 916,
#  'Force': 917,
#  'move': 918,
#  'Sambadrome': 919,
#  'gunshot': 920,
#  'villages': 921,
#  'customers': 922,
#  'prosecute': 923,
#  'arriving': 924,
#  'Sevilla': 925,
#  'anti-war': 926,
#  'so': 927,
#  'condolences': 928,
#  'western-style': 929,
#  'calm': 930,
#  'retain': 931,
#  'friendship': 932,
#  'Labor': 933,
#  'fate': 934,
#  'mid-year': 935,
#  '54,000': 936,
#  'temper': 937,
#  'hip': 938,
#  'enforcing': 939,
#  'Crown': 940,
#  'flyway': 941,
#  'Joint': 942,
#  'ambassadors': 943,
#  'Hotspur': 944,
#  'avert': 945,
#  'C': 946,
#  'trying': 947,
#  'Survey': 948,
#  'shutdown': 949,
#  'miracles': 950,
#  '1860s': 951,
#  'Chequers': 952,
#  'Zoellick': 953,
#  '314': 954,
#  'slash': 955,
#  'drain': 956,
#  'litigation': 957,
#  'southwestern': 958,
#  'bordered': 959,
#  'child': 960,
#  'replied': 961,
#  'pro-Hezbollah': 962,
#  'Mubarak': 963,
#  'auto': 964,
#  'madrassas': 965,
#  'boost': 966,
#  'ranging': 967,
#  'Pakistani-controlled': 968,
#  'tons': 969,
#  'highways': 970,
#  'Dushevina': 971,
#  'Plachkov': 972,
#  'honesty': 973,
#  'Zvornik': 974,
#  'focal': 975,
#  'p.m.': 976,
#  'hammered': 977,
#  'Duval': 978,
#  'justice': 979,
#  '1970': 980,
#  'rentals': 981,
#  'scoring': 982,
#  'Enriched': 983,
#  'Cindy': 984,
#  'profiled': 985,
#  'KNU': 986,
#  'Federico': 987,
#  'stores': 988,
#  'Jaafari': 989,
#  'configured': 990,
#  '2,711': 991,
#  'reversing': 992,
#  'wetlands': 993,
#  'a': 994,
#  'beasts': 995,
#  'Physician': 996,
#  'corporation': 997,
#  'H.W.': 998,
#  'wrong': 999,
#  ...}

# %%
ind_2_token=dict([(v,k) for k,v in tok_2_indx.items()])

# %%
ind_2_token
# Out:
# {0: '<UNK>',
#  1: '<PAD>',
#  2: 'Atambayev',
#  3: '1959',
#  4: 'beaches',
#  5: 'injure',
#  6: 'maneuvers',
#  7: 'Shujaat',
#  8: 'Caretaker',
#  9: 'affiliations',
#  10: 'manner',
#  11: 'disperse',
#  12: 'settlements',
#  13: 'XVI',
#  14: 'concert',
#  15: 'Shurpayev',
#  16: 'evading',
#  17: 'Chad',
#  18: 'drainage',
#  19: 'Abductees',
#  20: 'appalling',
#  21: 'unborn',
#  22: 'Hanssen-Bauer',
#  23: 'organizers',
#  24: 'Pyongyang',
#  25: 'crowds',
#  26: 'sedimentary',
#  27: 'Hsann',
#  28: 'plot',
#  29: 'sleeping',
#  30: 'climates',
#  31: 'teach',
#  32: 'equivalent',
#  33: 'speaks',
#  34: 'counts',
#  35: 'skirmish',
#  36: 'expert',
#  37: 'tracked',
#  38: 'Guerrero',
#  39: 'humiliating',
#  40: 'Geoscience',
#  41: 'Azeri',
#  42: '2',
#  43: 'Jordanian',
#  44: 'malls',
#  45: 'residents',
#  46: 'triumphs',
#  47: 'one-time',
#  48: 'bird',
#  49: '81',
#  50: 'Anbar',
#  51: 'celebrates',
#  52: 'Der',
#  53: 'Syrian-backed',
#  54: 'major',
#  55: 'COLUMBUS',
#  56: 'indicator',
#  57: 'stampede',
#  58: 'typically',
#  59: 'plots',
#  60: 'Crude',
#  61: 'supply',
#  62: 'owned',
#  63: 'foods',
#  64: 'Parasol',
#  65: 'inundated',
#  66: 'ways',
#  67: 'Although',
#  68: 'Arturo',
#  69: 'Omar',
#  70: 'cyanide-based',
#  71: 'Militants',
#  72: 'Bakili',
#  73: 'India',
#  74: 'bitterly',
#  75: 'Amerindian',
#  76: 'Jendayi',
#  77: 'Juventud',
#  78: 'assigned',
#  79: 'outbursts',
#  80: 'infrastructure',
#  81: 'collapse',
#  82: 'Syrians',
#  83: 'transition',
#  84: 'Bajaur',
#  85: 'fears',
#  86: 'Mladen',
#  87: 'waged',
#  88: 'Sirnak',
#  89: 'rubber',
#  90: 'thoughts',
#  91: 'Kunduz',
#  92: 'Roads',
#  93: 'sweltering',
#  94: 'trials',
#  95: 'Kids',
#  96: 'director',
#  97: 'meters',
#  98: 'scoundrel',
#  99: 'anti-retroviral',
#  100: 'Luzhkov',
#  101: 'heeds',
#  102: '1002',
#  103: 'Feeling',
#  104: 'Sex',
#  105: 'runs',
#  106: 'Labado',
#  107: '1,800',
#  108: '7,000',
#  109: 'booster',
#  110: 'Independent',
#  111: 'Kjetil',
#  112: 'dollar',
#  113: 'Return',
#  114: 'Nhlabatsi',
#  115: '4.1',
#  116: 'breast',
#  117: 'dwellers',
#  118: 'hope',
#  119: 'Sudeten',
#  120: '14-year',
#  121: 'handovers',
#  122: 'fairly',
#  123: 'Hooper',
#  124: 'heavily-armed',
#  125: 'sermon',
#  126: 'gangs',
#  127: 'al-Arabiya',
#  128: 'measurable',
#  129: 'bishop',
#  130: 'Greek-led',
#  131: 'volcanic',
#  132: 'socializing',
#  133: 'solar',
#  134: 'Monte',
#  135: 'recovered',
#  136: 'liquid',
#  137: 'sabotage',
#  138: 'excessively',
#  139: 'westerners',
#  140: 'platforms',
#  141: 'museum',
#  142: 'statistics',
#  143: 'revolution',
#  144: 'non-violent',
#  145: 'Grenada',
#  146: 'Richter',
#  147: 'makers',
#  148: 'group',
#  149: 'aliens',
#  150: 'ravine',
#  151: 'delayed',
#  152: '280',
#  153: 'Doha',
#  154: 'moans',
#  155: 'chairmanship',
#  156: 'retaliatory',
#  157: 'discussion',
#  158: 'Peru',
#  159: 'Lome',
#  160: 'ocean',
#  161: '111',
#  162: 'failing',
#  163: 'officers',
#  164: 'qualifying',
#  165: 'stab',
#  166: 'trust',
#  167: 'overland',
#  168: 'recently-elected',
#  169: 'Foreign',
#  170: 'militant-related',
#  171: 'overcame',
#  172: 'campaigns',
#  173: 'homage',
#  174: '39th',
#  175: 'kickbacks',
#  176: 'misdirected',
#  177: '06-Apr',
#  178: 'leaves',
#  179: 'profited',
#  180: 'Palmer',
#  181: 'GUELLEH',
#  182: 'immigrants',
#  183: 'holy',
#  184: 'surrendering',
#  185: 'eat',
#  186: '80-year-old',
#  187: 'pensioners',
#  188: 'decade',
#  189: 'rocket',
#  190: 'Dixie',
#  191: 'one-China',
#  192: 'echoing',
#  193: 'quarter-on-quarter',
#  194: 'goal',
#  195: 'semi',
#  196: 'city',
#  197: 'straight',
#  198: 'G',
#  199: 'treatment',
#  200: 'disgrace',
#  201: 'tomb',
#  202: 'Coast',
#  203: 'proved',
#  204: 'Karlovic',
#  205: 'Whittington',
#  206: 'contagious',
#  207: 'image',
#  208: 'Lieutenant-General',
#  209: 'wrangling',
#  210: 'Marcus',
#  211: 'outlandish',
#  212: 'trumped',
#  213: 'cigarettes',
#  214: 'Virunga',
#  215: 'adverse',
#  216: 'marine',
#  217: 'saved',
#  218: 'sirens',
#  219: 'reflects',
#  220: 'tunnels',
#  221: 'Livni',
#  222: 'function',
#  223: 'deal',
#  224: 'Yevpatoria',
#  225: 'prior',
#  226: 'crucial',
#  227: 'redraw',
#  228: '9th',
#  229: 'current',
#  230: 'somewhere',
#  231: 'Guatemalans',
#  232: 'U.N.-backed',
#  233: 'anti-Syrian',
#  234: 'informed',
#  235: 'promise',
#  236: 'Selim',
#  237: 'trafficking',
#  238: 'analysts',
#  239: 'Huy',
#  240: 'Amerzeb',
#  241: 'vowing',
#  242: 'Bombings',
#  243: 'arm',
#  244: 'demolish',
#  245: 'consuming',
#  246: '169',
#  247: 'security',
#  248: 'Akayev',
#  249: 'vastly',
#  250: 'Solidaria',
#  251: 'commanding',
#  252: 'Creole',
#  253: 'earners',
#  254: 'cheated',
#  255: 'Gunmen',
#  256: 'Dany',
#  257: 'Kwan',
#  258: 'candy',
#  259: 'pilotless',
#  260: 'predicted',
#  261: 'marchers',
#  262: 'Civil',
#  263: 'bowler',
#  264: 'Fallujans',
#  265: 'unlawfully',
#  266: 'Due',
#  267: 'folks',
#  268: 'unfurling',
#  269: 'avoidance',
#  270: 'Traditional',
#  271: '65-year-old',
#  272: 'Gaston',
#  273: 'fishing',
#  274: 'sang',
#  275: 'falciparum',
#  276: 'Muzaffarabad',
#  277: 'rains',
#  278: 'Azeris',
#  279: 'appointee',
#  280: 'ca.',
#  281: 'rest',
#  282: 'territorial',
#  283: 'whale',
#  284: 'insolent',
#  285: 'Amir',
#  286: 'Taiwanese',
#  287: 'traces',
#  288: 'surges',
#  289: 'Hogg',
#  290: 'Distribution',
#  291: 'wants',
#  292: 'Al-Ghoul',
#  293: 'Philippines',
#  294: 'discipline',
#  295: 'abstaining',
#  296: 'passport',
#  297: 'Mladic',
#  298: 'subtracted',
#  299: 'dealers',
#  300: 'occupies',
#  301: 'Goods',
#  302: 'Fleihan',
#  303: 'confirming',
#  304: 'pure',
#  305: 'Plains',
#  306: 'head',
#  307: 'Israeli',
#  308: 'Channu',
#  309: 'investigation',
#  310: 'nullified',
#  311: 'gratitude',
#  312: 'Ayatollah',
#  313: 'work',
#  314: 'Singer',
#  315: 'Iyad',
#  316: 'blows',
#  317: 'fewer',
#  318: '453',
#  319: 'Taliban-linked',
#  320: 'ruthless',
#  321: 'anti-corruption',
#  322: 'tours',
#  323: 'sort',
#  324: 'Transparency',
#  325: 'belonged',
#  326: 'raids',
#  327: 'peacekeeping',
#  328: 'casualties',
#  329: 'slap',
#  330: 'Agha',
#  331: 'Chernobyl',
#  332: 'Michigan',
#  333: 'headbands',
#  334: 'Tharanga',
#  335: 'victims',
#  336: 'suppressing',
#  337: 'Rauf',
#  338: 'hamper',
#  339: 'blame',
#  340: 'fitness',
#  341: 'placed',
#  342: 'soften',
#  343: '28,000',
#  344: 'prey',
#  345: 'Breeze',
#  346: 'Six',
#  347: 'racism',
#  348: 'Square',
#  349: 'updates',
#  350: 'Acquisition',
#  351: 'rife',
#  352: 'missile',
#  353: 'preserving',
#  354: 'Dawei-Ye',
#  355: 'ongoing',
#  356: 'Shinzo',
#  357: 'stamp',
#  358: 'Hungary',
#  359: 'Ernest',
#  360: 'prefer',
#  361: 'Doe',
#  362: 'Yankee',
#  363: 'shared',
#  364: 'Chargers',
#  365: 'homeowner',
#  366: 'Kel',
#  367: '2002',
#  368: 'Snagovo',
#  369: 'Rubina',
#  370: 'runways',
#  371: 'confirmed',
#  372: 'He',
#  373: 'flown',
#  374: 'resold',
#  375: '9.00',
#  376: 'Madhoun',
#  377: 'Society',
#  378: 'illustrates',
#  379: 'disagrees',
#  380: '120',
#  381: 'contract',
#  382: 'fast',
#  383: 'Nour',
#  384: 'controversy',
#  385: 'uprising',
#  386: 'economies',
#  387: 'Nuclear',
#  388: 'bastion',
#  389: 'Negotiations',
#  390: '1,700',
#  391: '380',
#  392: 'alpine',
#  393: 'wealthier',
#  394: 'paralysis',
#  395: 'minorities',
#  396: 'Islamists',
#  397: 'Kuchma',
#  398: 'Qazi',
#  399: 'Israeli-Lebanese',
#  400: 'wealthiest',
#  401: 'website',
#  402: 'number-two',
#  403: 'insurgency',
#  404: 'street-to-street',
#  405: 'losers',
#  406: 'stint',
#  407: 'tracker',
#  408: 'hometown',
#  409: 'unannounced',
#  410: 'significant',
#  411: 'fled',
#  412: 'demolition',
#  413: 'fold',
#  414: 'Prosecutor',
#  415: 'railroad',
#  416: 'shielded',
#  417: 'Arab',
#  418: 'Cholera',
#  419: 'electronically',
#  420: 'Amendment',
#  421: 'Chinese-sanctioned',
#  422: 'Groenefeld',
#  423: 'Dharmeratnam',
#  424: 'Pak',
#  425: 'clamp',
#  426: 'Bagram',
#  427: '1,60,000',
#  428: 'Norwegian',
#  429: 'El-Arish',
#  430: 'abducting',
#  431: 'hurting',
#  432: 'fourth-seeded',
#  433: 'registering',
#  434: 'Warri',
#  435: 'endorsement',
#  436: 'Goats',
#  437: 'wings',
#  438: 'Burma-Thailand',
#  439: 'temporarily',
#  440: 'hosted',
#  441: 'Arlington',
#  442: 'Small',
#  443: 'morally',
#  444: 'Aye',
#  445: 'locales',
#  446: 'complicity',
#  447: 'Soldiers',
#  448: 'off-duty',
#  449: 'Delgado',
#  450: 'kilograms',
#  451: 'conduct',
#  452: 'taunting',
#  453: 'catheterization',
#  454: 'towering',
#  455: 'rode',
#  456: 'Kuwaiti',
#  457: 'Khaled',
#  458: 'Ohrid',
#  459: 'Serbia-Montenegro',
#  460: 'strife',
#  461: 'confidence-building',
#  462: 'cut',
#  463: 'Orenburg',
#  464: 'Hubei',
#  465: 'kidney',
#  466: '225-seat',
#  467: 'hijacker',
#  468: 'E.U',
#  469: 'Sharm-el-Sheik',
#  470: 'culling',
#  471: 'native',
#  472: 'drink',
#  473: 'Izvestia',
#  474: 'multilaterals',
#  475: 'videotape',
#  476: 'News-agency',
#  477: 'stronghold',
#  478: 'character',
#  479: 'information',
#  480: 'checkpoints',
#  481: 'revealed',
#  482: 'October',
#  483: 'motive',
#  484: 'enhancing',
#  485: 'touches',
#  486: 'U.S.-India',
#  487: 'Nice',
#  488: 'clerics',
#  489: 'Abdul',
#  490: 'Latin',
#  491: 'Kaczynski',
#  492: 'facilitator',
#  493: 'northeastern',
#  494: 'mandate',
#  495: 'narrates',
#  496: 'Dom',
#  497: 'probably',
#  498: 'importance',
#  499: 'produced',
#  500: 'tried',
#  501: 'mid-November',
#  502: 'previously',
#  503: 'technical',
#  504: 'secular',
#  505: 'take',
#  506: 'incitement',
#  507: 'miracle',
#  508: 'rugged',
#  509: 'Valdas',
#  510: 'Bassel',
#  511: 'homelands',
#  512: 'boycott',
#  513: 'stalking',
#  514: 'Batad',
#  515: 'gems',
#  516: 'looser',
#  517: '4,200',
#  518: 'annulled',
#  519: 'decent',
#  520: 're-establishing',
#  521: 'Racism',
#  522: 'Abu',
#  523: '1,74,000',
#  524: 'overflowed',
#  525: 'Harlan',
#  526: 'if',
#  527: 'stocks',
#  528: 'acquisition',
#  529: 'Amid',
#  530: 'meeting',
#  531: 'observer',
#  532: 'injected',
#  533: 'disappointed',
#  534: 'May',
#  535: 'tolerant',
#  536: 'luxuries',
#  537: 'complete',
#  538: 'emergencies',
#  539: 'preserve',
#  540: 'shrines',
#  541: 'Shiloh',
#  542: 'comprehend',
#  543: 'slam',
#  544: 'civil',
#  545: 'clients',
#  546: 'investigating',
#  547: 'counted',
#  548: 'Ashkelon',
#  549: 'atrocities',
#  550: 'stockpiling',
#  551: 'organs',
#  552: 'American-Islamic',
#  553: 'withdrawal',
#  554: 'Alexis',
#  555: 'documents',
#  556: 'Bramble',
#  557: 'attackers',
#  558: 'touched',
#  559: 'travels',
#  560: 'slow',
#  561: 'unskilled',
#  562: 'Hashemi',
#  563: 'erosion',
#  564: 'runway',
#  565: 'final',
#  566: 'D-Ohio',
#  567: 'prayed',
#  568: 'vaccination',
#  569: 'Mussolini',
#  570: 'Alan',
#  571: 'Ulus',
#  572: 'ability',
#  573: 'dual',
#  574: '61,000',
#  575: 'record-setting',
#  576: 'equalizer',
#  577: 'Carli',
#  578: 'drugs',
#  579: 'manifesto',
#  580: 'birthplace',
#  581: 'distinctive',
#  582: 'coming',
#  583: 'questionable',
#  584: 'Naval',
#  585: 'filed',
#  586: 'Border',
#  587: 'Gnassingbe',
#  588: 'provider',
#  589: 'Kharrazi',
#  590: 'hardship',
#  591: 'Rams',
#  592: 'ticket',
#  593: 'now-defunct',
#  594: 'Bernal',
#  595: 'Sequi',
#  596: 'Pushpa',
#  597: 'Huon',
#  598: 'Schroeder',
#  599: 'Statoil',
#  600: 'belong',
#  601: 'good',
#  602: 'course',
#  603: 'Kakooza',
#  604: 'Boldak',
#  605: 'EDT',
#  606: 'Teshiktosh',
#  607: 'soared',
#  608: '23rd',
#  609: 'buyouts',
#  610: 'tolerated',
#  611: 'Albania',
#  612: 'supplement',
#  613: 'ACLU',
#  614: 'obvious',
#  615: 'US-Central',
#  616: 'tell',
#  617: 'jaws',
#  618: 'NLD',
#  619: 'nationwide',
#  620: 'Number',
#  621: 'then-President',
#  622: 'performing',
#  623: 'restored',
#  624: 'trigger',
#  625: 'consequences',
#  626: 'membership',
#  627: 'underlying',
#  628: 'economic',
#  629: 'Rafah',
#  630: 'amass',
#  631: 'Leasing',
#  632: 'Administrative',
#  633: 'cocked',
#  634: 'Why',
#  635: 'Financial',
#  636: 'Than',
#  637: 'conference',
#  638: 'fabricating',
#  639: 'steer',
#  640: 'Safina',
#  641: 'nullify',
#  642: 'SMART',
#  643: 'efforts',
#  644: 'conversion',
#  645: 'fright',
#  646: 'any',
#  647: 'smashing',
#  648: 'ago',
#  649: 'patrolling',
#  650: 'fused',
#  651: 'Sawyer',
#  652: 'search',
#  653: 'Falcons',
#  654: 'incited',
#  655: 'implications',
#  656: 'provide',
#  657: 'spills',
#  658: 'wars',
#  659: 'Condolezza',
#  660: 'electrocution',
#  661: 'Tetiana',
#  662: 'encouraging',
#  663: 'washed',
#  664: 'European-brokered',
#  665: 'Wam',
#  666: 'rand',
#  667: 'Twelve',
#  668: 'data',
#  669: 'marshy',
#  670: 'interests',
#  671: 'scrapped',
#  672: 'Fort',
#  673: 'exploration',
#  674: 'Harbhajan',
#  675: 'expires',
#  676: 'panels',
#  677: 'Katrina',
#  678: 'guarantee',
#  679: 'defenders',
#  680: 'Beijing-based',
#  681: 'Colom',
#  682: 'member-nations',
#  683: 'self-governing',
#  684: 'disciplined',
#  685: 'Dabas',
#  686: 'Conoco',
#  687: 'cane',
#  688: 'Revolution',
#  689: 'Croat',
#  690: '45',
#  691: 'Duke',
#  692: 'will',
#  693: 'working',
#  694: 'residing',
#  695: 'Accidents',
#  696: '1839',
#  697: 'Kamdesh',
#  698: 'martial',
#  699: 'national-level',
#  700: 'billionaire',
#  701: 'Joseph',
#  702: 'gaps',
#  703: 'cancellation',
#  704: 'future',
#  705: 'tourism',
#  706: 'covertly',
#  707: 'Eelam',
#  708: 'cheeks',
#  709: 'Thirty-one-year-old',
#  710: 'Mahsouli',
#  711: 'price',
#  712: 'wedding',
#  713: 'Macedonian-American',
#  714: 'threats',
#  715: 'Alexandria',
#  716: 'BBC',
#  717: 'occupied',
#  718: 'tiny',
#  719: 'Fox',
#  720: 'Kurdistan',
#  721: 'abuses',
#  722: '1,170',
#  723: 'Vines',
#  724: 'modestly',
#  725: 'Noor',
#  726: 'directive',
#  727: 'non-governmental',
#  728: 'meant',
#  729: 'Sarah',
#  730: 'band',
#  731: 'Maddalena',
#  732: 'headline',
#  733: 'Smaller',
#  734: 'Mahmud',
#  735: 'peg',
#  736: 'Beatrice',
#  737: 'Palma',
#  738: 'Sangin',
#  739: 'peninsula',
#  740: 'sheriff',
#  741: 'filmmaker',
#  742: '1498',
#  743: 'rates',
#  744: 're-vote',
#  745: 'state-funded',
#  746: 'co-educational',
#  747: 'Caribbean',
#  748: 'French-Colombian',
#  749: '1.1',
#  750: 'arisen',
#  751: 'human',
#  752: 'ships',
#  753: 'Brazil',
#  754: 'Hiroyuki',
#  755: 'phoenixes',
#  756: '125',
#  757: 'Gurage',
#  758: 'must',
#  759: 'rendered',
#  760: 'truncated',
#  761: 'accession',
#  762: 'Enlargement',
#  763: 'U.N.',
#  764: 'Qais',
#  765: 'observing',
#  766: 'Velvet',
#  767: 'consented',
#  768: 'Zaken',
#  769: 'Citroën',
#  770: 'Defectors',
#  771: 'toys',
#  772: 'escorted',
#  773: 'Haradinaj',
#  774: 'red-shirts',
#  775: 'Separately',
#  776: '39',
#  777: '1,55,000',
#  778: 'leaders',
#  779: 'Ritchie',
#  780: 'Law',
#  781: 'ingratitude',
#  782: 'British-based',
#  783: 'Cavaco',
#  784: 'praying',
#  785: 'privatized',
#  786: 'basket',
#  787: 'apartment',
#  788: 'lawyer-activist',
#  789: 'parents',
#  790: 'Hausa',
#  791: 'universally',
#  792: 'Silvan',
#  793: 'Seville',
#  794: 'win',
#  795: 'Center',
#  796: 'Pascal',
#  797: 'innocence',
#  798: 'paintings',
#  799: 'consisting',
#  800: 'nationalists',
#  801: 'riding',
#  802: 'Kathmandu',
#  803: 'Himalayas',
#  804: 'Jehan',
#  805: 'voices',
#  806: 'total',
#  807: 'economist',
#  808: 'trial',
#  809: 'decreed',
#  810: 'found',
#  811: 'slowed',
#  812: 'hanged',
#  813: '\x97',
#  814: 'plantation',
#  815: 'apparel',
#  816: 'Shanksville',
#  817: 'Chernikhov',
#  818: 'shake',
#  819: 'five-decade',
#  820: 'neighborhood',
#  821: 'Oxford',
#  822: 'causing',
#  823: 'characterized',
#  824: 'reconciliation',
#  825: 'Nicaragua',
#  826: 'Texmelucan',
#  827: 'Bajur',
#  828: 'patent',
#  829: 'star-studded',
#  830: 'consultation',
#  831: 'Doctors',
#  832: 'pictures',
#  833: 'al-Hariri',
#  834: 'disparity',
#  835: 'proposal',
#  836: 'rocket-propelled',
#  837: 'Investors',
#  838: 'Hamza',
#  839: 'foliage',
#  840: 'Guadalupe',
#  841: 'firearms',
#  842: 'Disasters',
#  843: 'poisoning',
#  844: 'largely',
#  845: 'legalizing',
#  846: 'moments',
#  847: 'trillions',
#  848: 'idleness',
#  849: 'ranges',
#  850: 'rigorous',
#  851: 'radical',
#  852: 'matters',
#  853: 'ribbon',
#  854: 'test-fired',
#  855: 'factories',
#  856: 'seem',
#  857: 'Jawed',
#  858: 'slightly',
#  859: 'Trade',
#  860: 'maltreated',
#  861: 'non-Jews',
#  862: 'Prague',
#  863: 'fertile',
#  864: 'Lage',
#  865: 'Providencia',
#  866: 'indulging',
#  867: 'Peineta',
#  868: 'kilted',
#  869: 'interpreting',
#  870: 'costly',
#  871: 'Namibia',
#  872: 'large-scale',
#  873: 'Kasuri',
#  874: 'Burton',
#  875: 'spying',
#  876: 'Chung',
#  877: 'Hit',
#  878: 'abductors',
#  879: 'regain',
#  880: '[',
#  881: '300',
#  882: 'retribution',
#  883: 'Khalis',
#  884: 'dividend',
#  885: 'laughing',
#  886: 'Naked',
#  887: 'Team',
#  888: 'Substantial',
#  889: 'create',
#  890: 'exhumed',
#  891: 'testified',
#  892: 'orderly',
#  893: 'U.S.-educated',
#  894: 'Gbagbo',
#  895: 'addressed',
#  896: 'Organization',
#  897: 'Ismail',
#  898: 'unreliable',
#  899: 'Facility',
#  900: 'containing',
#  901: 'hitch',
#  902: 'Roosevelt',
#  903: 'Pelosi',
#  904: 'auctioneers',
#  905: 'Rohani',
#  906: 'sealing',
#  907: 'Cowell',
#  908: 'Reich',
#  909: 'date',
#  910: 'Zapatista',
#  911: 'populous',
#  912: 'grids',
#  913: 'Adnan',
#  914: '\x96',
#  915: 'kinds',
#  916: 'sanction',
#  917: 'Force',
#  918: 'move',
#  919: 'Sambadrome',
#  920: 'gunshot',
#  921: 'villages',
#  922: 'customers',
#  923: 'prosecute',
#  924: 'arriving',
#  925: 'Sevilla',
#  926: 'anti-war',
#  927: 'so',
#  928: 'condolences',
#  929: 'western-style',
#  930: 'calm',
#  931: 'retain',
#  932: 'friendship',
#  933: 'Labor',
#  934: 'fate',
#  935: 'mid-year',
#  936: '54,000',
#  937: 'temper',
#  938: 'hip',
#  939: 'enforcing',
#  940: 'Crown',
#  941: 'flyway',
#  942: 'Joint',
#  943: 'ambassadors',
#  944: 'Hotspur',
#  945: 'avert',
#  946: 'C',
#  947: 'trying',
#  948: 'Survey',
#  949: 'shutdown',
#  950: 'miracles',
#  951: '1860s',
#  952: 'Chequers',
#  953: 'Zoellick',
#  954: '314',
#  955: 'slash',
#  956: 'drain',
#  957: 'litigation',
#  958: 'southwestern',
#  959: 'bordered',
#  960: 'child',
#  961: 'replied',
#  962: 'pro-Hezbollah',
#  963: 'Mubarak',
#  964: 'auto',
#  965: 'madrassas',
#  966: 'boost',
#  967: 'ranging',
#  968: 'Pakistani-controlled',
#  969: 'tons',
#  970: 'highways',
#  971: 'Dushevina',
#  972: 'Plachkov',
#  973: 'honesty',
#  974: 'Zvornik',
#  975: 'focal',
#  976: 'p.m.',
#  977: 'hammered',
#  978: 'Duval',
#  979: 'justice',
#  980: '1970',
#  981: 'rentals',
#  982: 'scoring',
#  983: 'Enriched',
#  984: 'Cindy',
#  985: 'profiled',
#  986: 'KNU',
#  987: 'Federico',
#  988: 'stores',
#  989: 'Jaafari',
#  990: 'configured',
#  991: '2,711',
#  992: 'reversing',
#  993: 'wetlands',
#  994: 'a',
#  995: 'beasts',
#  996: 'Physician',
#  997: 'corporation',
#  998: 'H.W.',
#  999: 'wrong',
#  ...}

# %%
#PAD is for token id 1
#UNK is for token id 0

# %%
tag_2_indx=dict([(k,v) for v,k in enumerate(unique_tags)])

# %%
indx_2_tag=dict([(k,v) for v,k in tag_2_indx.items()])

# %%
tok_2_indx
# Out:
# {'<UNK>': 0,
#  '<PAD>': 1,
#  'Atambayev': 2,
#  '1959': 3,
#  'beaches': 4,
#  'injure': 5,
#  'maneuvers': 6,
#  'Shujaat': 7,
#  'Caretaker': 8,
#  'affiliations': 9,
#  'manner': 10,
#  'disperse': 11,
#  'settlements': 12,
#  'XVI': 13,
#  'concert': 14,
#  'Shurpayev': 15,
#  'evading': 16,
#  'Chad': 17,
#  'drainage': 18,
#  'Abductees': 19,
#  'appalling': 20,
#  'unborn': 21,
#  'Hanssen-Bauer': 22,
#  'organizers': 23,
#  'Pyongyang': 24,
#  'crowds': 25,
#  'sedimentary': 26,
#  'Hsann': 27,
#  'plot': 28,
#  'sleeping': 29,
#  'climates': 30,
#  'teach': 31,
#  'equivalent': 32,
#  'speaks': 33,
#  'counts': 34,
#  'skirmish': 35,
#  'expert': 36,
#  'tracked': 37,
#  'Guerrero': 38,
#  'humiliating': 39,
#  'Geoscience': 40,
#  'Azeri': 41,
#  '2': 42,
#  'Jordanian': 43,
#  'malls': 44,
#  'residents': 45,
#  'triumphs': 46,
#  'one-time': 47,
#  'bird': 48,
#  '81': 49,
#  'Anbar': 50,
#  'celebrates': 51,
#  'Der': 52,
#  'Syrian-backed': 53,
#  'major': 54,
#  'COLUMBUS': 55,
#  'indicator': 56,
#  'stampede': 57,
#  'typically': 58,
#  'plots': 59,
#  'Crude': 60,
#  'supply': 61,
#  'owned': 62,
#  'foods': 63,
#  'Parasol': 64,
#  'inundated': 65,
#  'ways': 66,
#  'Although': 67,
#  'Arturo': 68,
#  'Omar': 69,
#  'cyanide-based': 70,
#  'Militants': 71,
#  'Bakili': 72,
#  'India': 73,
#  'bitterly': 74,
#  'Amerindian': 75,
#  'Jendayi': 76,
#  'Juventud': 77,
#  'assigned': 78,
#  'outbursts': 79,
#  'infrastructure': 80,
#  'collapse': 81,
#  'Syrians': 82,
#  'transition': 83,
#  'Bajaur': 84,
#  'fears': 85,
#  'Mladen': 86,
#  'waged': 87,
#  'Sirnak': 88,
#  'rubber': 89,
#  'thoughts': 90,
#  'Kunduz': 91,
#  'Roads': 92,
#  'sweltering': 93,
#  'trials': 94,
#  'Kids': 95,
#  'director': 96,
#  'meters': 97,
#  'scoundrel': 98,
#  'anti-retroviral': 99,
#  'Luzhkov': 100,
#  'heeds': 101,
#  '1002': 102,
#  'Feeling': 103,
#  'Sex': 104,
#  'runs': 105,
#  'Labado': 106,
#  '1,800': 107,
#  '7,000': 108,
#  'booster': 109,
#  'Independent': 110,
#  'Kjetil': 111,
#  'dollar': 112,
#  'Return': 113,
#  'Nhlabatsi': 114,
#  '4.1': 115,
#  'breast': 116,
#  'dwellers': 117,
#  'hope': 118,
#  'Sudeten': 119,
#  '14-year': 120,
#  'handovers': 121,
#  'fairly': 122,
#  'Hooper': 123,
#  'heavily-armed': 124,
#  'sermon': 125,
#  'gangs': 126,
#  'al-Arabiya': 127,
#  'measurable': 128,
#  'bishop': 129,
#  'Greek-led': 130,
#  'volcanic': 131,
#  'socializing': 132,
#  'solar': 133,
#  'Monte': 134,
#  'recovered': 135,
#  'liquid': 136,
#  'sabotage': 137,
#  'excessively': 138,
#  'westerners': 139,
#  'platforms': 140,
#  'museum': 141,
#  'statistics': 142,
#  'revolution': 143,
#  'non-violent': 144,
#  'Grenada': 145,
#  'Richter': 146,
#  'makers': 147,
#  'group': 148,
#  'aliens': 149,
#  'ravine': 150,
#  'delayed': 151,
#  '280': 152,
#  'Doha': 153,
#  'moans': 154,
#  'chairmanship': 155,
#  'retaliatory': 156,
#  'discussion': 157,
#  'Peru': 158,
#  'Lome': 159,
#  'ocean': 160,
#  '111': 161,
#  'failing': 162,
#  'officers': 163,
#  'qualifying': 164,
#  'stab': 165,
#  'trust': 166,
#  'overland': 167,
#  'recently-elected': 168,
#  'Foreign': 169,
#  'militant-related': 170,
#  'overcame': 171,
#  'campaigns': 172,
#  'homage': 173,
#  '39th': 174,
#  'kickbacks': 175,
#  'misdirected': 176,
#  '06-Apr': 177,
#  'leaves': 178,
#  'profited': 179,
#  'Palmer': 180,
#  'GUELLEH': 181,
#  'immigrants': 182,
#  'holy': 183,
#  'surrendering': 184,
#  'eat': 185,
#  '80-year-old': 186,
#  'pensioners': 187,
#  'decade': 188,
#  'rocket': 189,
#  'Dixie': 190,
#  'one-China': 191,
#  'echoing': 192,
#  'quarter-on-quarter': 193,
#  'goal': 194,
#  'semi': 195,
#  'city': 196,
#  'straight': 197,
#  'G': 198,
#  'treatment': 199,
#  'disgrace': 200,
#  'tomb': 201,
#  'Coast': 202,
#  'proved': 203,
#  'Karlovic': 204,
#  'Whittington': 205,
#  'contagious': 206,
#  'image': 207,
#  'Lieutenant-General': 208,
#  'wrangling': 209,
#  'Marcus': 210,
#  'outlandish': 211,
#  'trumped': 212,
#  'cigarettes': 213,
#  'Virunga': 214,
#  'adverse': 215,
#  'marine': 216,
#  'saved': 217,
#  'sirens': 218,
#  'reflects': 219,
#  'tunnels': 220,
#  'Livni': 221,
#  'function': 222,
#  'deal': 223,
#  'Yevpatoria': 224,
#  'prior': 225,
#  'crucial': 226,
#  'redraw': 227,
#  '9th': 228,
#  'current': 229,
#  'somewhere': 230,
#  'Guatemalans': 231,
#  'U.N.-backed': 232,
#  'anti-Syrian': 233,
#  'informed': 234,
#  'promise': 235,
#  'Selim': 236,
#  'trafficking': 237,
#  'analysts': 238,
#  'Huy': 239,
#  'Amerzeb': 240,
#  'vowing': 241,
#  'Bombings': 242,
#  'arm': 243,
#  'demolish': 244,
#  'consuming': 245,
#  '169': 246,
#  'security': 247,
#  'Akayev': 248,
#  'vastly': 249,
#  'Solidaria': 250,
#  'commanding': 251,
#  'Creole': 252,
#  'earners': 253,
#  'cheated': 254,
#  'Gunmen': 255,
#  'Dany': 256,
#  'Kwan': 257,
#  'candy': 258,
#  'pilotless': 259,
#  'predicted': 260,
#  'marchers': 261,
#  'Civil': 262,
#  'bowler': 263,
#  'Fallujans': 264,
#  'unlawfully': 265,
#  'Due': 266,
#  'folks': 267,
#  'unfurling': 268,
#  'avoidance': 269,
#  'Traditional': 270,
#  '65-year-old': 271,
#  'Gaston': 272,
#  'fishing': 273,
#  'sang': 274,
#  'falciparum': 275,
#  'Muzaffarabad': 276,
#  'rains': 277,
#  'Azeris': 278,
#  'appointee': 279,
#  'ca.': 280,
#  'rest': 281,
#  'territorial': 282,
#  'whale': 283,
#  'insolent': 284,
#  'Amir': 285,
#  'Taiwanese': 286,
#  'traces': 287,
#  'surges': 288,
#  'Hogg': 289,
#  'Distribution': 290,
#  'wants': 291,
#  'Al-Ghoul': 292,
#  'Philippines': 293,
#  'discipline': 294,
#  'abstaining': 295,
#  'passport': 296,
#  'Mladic': 297,
#  'subtracted': 298,
#  'dealers': 299,
#  'occupies': 300,
#  'Goods': 301,
#  'Fleihan': 302,
#  'confirming': 303,
#  'pure': 304,
#  'Plains': 305,
#  'head': 306,
#  'Israeli': 307,
#  'Channu': 308,
#  'investigation': 309,
#  'nullified': 310,
#  'gratitude': 311,
#  'Ayatollah': 312,
#  'work': 313,
#  'Singer': 314,
#  'Iyad': 315,
#  'blows': 316,
#  'fewer': 317,
#  '453': 318,
#  'Taliban-linked': 319,
#  'ruthless': 320,
#  'anti-corruption': 321,
#  'tours': 322,
#  'sort': 323,
#  'Transparency': 324,
#  'belonged': 325,
#  'raids': 326,
#  'peacekeeping': 327,
#  'casualties': 328,
#  'slap': 329,
#  'Agha': 330,
#  'Chernobyl': 331,
#  'Michigan': 332,
#  'headbands': 333,
#  'Tharanga': 334,
#  'victims': 335,
#  'suppressing': 336,
#  'Rauf': 337,
#  'hamper': 338,
#  'blame': 339,
#  'fitness': 340,
#  'placed': 341,
#  'soften': 342,
#  '28,000': 343,
#  'prey': 344,
#  'Breeze': 345,
#  'Six': 346,
#  'racism': 347,
#  'Square': 348,
#  'updates': 349,
#  'Acquisition': 350,
#  'rife': 351,
#  'missile': 352,
#  'preserving': 353,
#  'Dawei-Ye': 354,
#  'ongoing': 355,
#  'Shinzo': 356,
#  'stamp': 357,
#  'Hungary': 358,
#  'Ernest': 359,
#  'prefer': 360,
#  'Doe': 361,
#  'Yankee': 362,
#  'shared': 363,
#  'Chargers': 364,
#  'homeowner': 365,
#  'Kel': 366,
#  '2002': 367,
#  'Snagovo': 368,
#  'Rubina': 369,
#  'runways': 370,
#  'confirmed': 371,
#  'He': 372,
#  'flown': 373,
#  'resold': 374,
#  '9.00': 375,
#  'Madhoun': 376,
#  'Society': 377,
#  'illustrates': 378,
#  'disagrees': 379,
#  '120': 380,
#  'contract': 381,
#  'fast': 382,
#  'Nour': 383,
#  'controversy': 384,
#  'uprising': 385,
#  'economies': 386,
#  'Nuclear': 387,
#  'bastion': 388,
#  'Negotiations': 389,
#  '1,700': 390,
#  '380': 391,
#  'alpine': 392,
#  'wealthier': 393,
#  'paralysis': 394,
#  'minorities': 395,
#  'Islamists': 396,
#  'Kuchma': 397,
#  'Qazi': 398,
#  'Israeli-Lebanese': 399,
#  'wealthiest': 400,
#  'website': 401,
#  'number-two': 402,
#  'insurgency': 403,
#  'street-to-street': 404,
#  'losers': 405,
#  'stint': 406,
#  'tracker': 407,
#  'hometown': 408,
#  'unannounced': 409,
#  'significant': 410,
#  'fled': 411,
#  'demolition': 412,
#  'fold': 413,
#  'Prosecutor': 414,
#  'railroad': 415,
#  'shielded': 416,
#  'Arab': 417,
#  'Cholera': 418,
#  'electronically': 419,
#  'Amendment': 420,
#  'Chinese-sanctioned': 421,
#  'Groenefeld': 422,
#  'Dharmeratnam': 423,
#  'Pak': 424,
#  'clamp': 425,
#  'Bagram': 426,
#  '1,60,000': 427,
#  'Norwegian': 428,
#  'El-Arish': 429,
#  'abducting': 430,
#  'hurting': 431,
#  'fourth-seeded': 432,
#  'registering': 433,
#  'Warri': 434,
#  'endorsement': 435,
#  'Goats': 436,
#  'wings': 437,
#  'Burma-Thailand': 438,
#  'temporarily': 439,
#  'hosted': 440,
#  'Arlington': 441,
#  'Small': 442,
#  'morally': 443,
#  'Aye': 444,
#  'locales': 445,
#  'complicity': 446,
#  'Soldiers': 447,
#  'off-duty': 448,
#  'Delgado': 449,
#  'kilograms': 450,
#  'conduct': 451,
#  'taunting': 452,
#  'catheterization': 453,
#  'towering': 454,
#  'rode': 455,
#  'Kuwaiti': 456,
#  'Khaled': 457,
#  'Ohrid': 458,
#  'Serbia-Montenegro': 459,
#  'strife': 460,
#  'confidence-building': 461,
#  'cut': 462,
#  'Orenburg': 463,
#  'Hubei': 464,
#  'kidney': 465,
#  '225-seat': 466,
#  'hijacker': 467,
#  'E.U': 468,
#  'Sharm-el-Sheik': 469,
#  'culling': 470,
#  'native': 471,
#  'drink': 472,
#  'Izvestia': 473,
#  'multilaterals': 474,
#  'videotape': 475,
#  'News-agency': 476,
#  'stronghold': 477,
#  'character': 478,
#  'information': 479,
#  'checkpoints': 480,
#  'revealed': 481,
#  'October': 482,
#  'motive': 483,
#  'enhancing': 484,
#  'touches': 485,
#  'U.S.-India': 486,
#  'Nice': 487,
#  'clerics': 488,
#  'Abdul': 489,
#  'Latin': 490,
#  'Kaczynski': 491,
#  'facilitator': 492,
#  'northeastern': 493,
#  'mandate': 494,
#  'narrates': 495,
#  'Dom': 496,
#  'probably': 497,
#  'importance': 498,
#  'produced': 499,
#  'tried': 500,
#  'mid-November': 501,
#  'previously': 502,
#  'technical': 503,
#  'secular': 504,
#  'take': 505,
#  'incitement': 506,
#  'miracle': 507,
#  'rugged': 508,
#  'Valdas': 509,
#  'Bassel': 510,
#  'homelands': 511,
#  'boycott': 512,
#  'stalking': 513,
#  'Batad': 514,
#  'gems': 515,
#  'looser': 516,
#  '4,200': 517,
#  'annulled': 518,
#  'decent': 519,
#  're-establishing': 520,
#  'Racism': 521,
#  'Abu': 522,
#  '1,74,000': 523,
#  'overflowed': 524,
#  'Harlan': 525,
#  'if': 526,
#  'stocks': 527,
#  'acquisition': 528,
#  'Amid': 529,
#  'meeting': 530,
#  'observer': 531,
#  'injected': 532,
#  'disappointed': 533,
#  'May': 534,
#  'tolerant': 535,
#  'luxuries': 536,
#  'complete': 537,
#  'emergencies': 538,
#  'preserve': 539,
#  'shrines': 540,
#  'Shiloh': 541,
#  'comprehend': 542,
#  'slam': 543,
#  'civil': 544,
#  'clients': 545,
#  'investigating': 546,
#  'counted': 547,
#  'Ashkelon': 548,
#  'atrocities': 549,
#  'stockpiling': 550,
#  'organs': 551,
#  'American-Islamic': 552,
#  'withdrawal': 553,
#  'Alexis': 554,
#  'documents': 555,
#  'Bramble': 556,
#  'attackers': 557,
#  'touched': 558,
#  'travels': 559,
#  'slow': 560,
#  'unskilled': 561,
#  'Hashemi': 562,
#  'erosion': 563,
#  'runway': 564,
#  'final': 565,
#  'D-Ohio': 566,
#  'prayed': 567,
#  'vaccination': 568,
#  'Mussolini': 569,
#  'Alan': 570,
#  'Ulus': 571,
#  'ability': 572,
#  'dual': 573,
#  '61,000': 574,
#  'record-setting': 575,
#  'equalizer': 576,
#  'Carli': 577,
#  'drugs': 578,
#  'manifesto': 579,
#  'birthplace': 580,
#  'distinctive': 581,
#  'coming': 582,
#  'questionable': 583,
#  'Naval': 584,
#  'filed': 585,
#  'Border': 586,
#  'Gnassingbe': 587,
#  'provider': 588,
#  'Kharrazi': 589,
#  'hardship': 590,
#  'Rams': 591,
#  'ticket': 592,
#  'now-defunct': 593,
#  'Bernal': 594,
#  'Sequi': 595,
#  'Pushpa': 596,
#  'Huon': 597,
#  'Schroeder': 598,
#  'Statoil': 599,
#  'belong': 600,
#  'good': 601,
#  'course': 602,
#  'Kakooza': 603,
#  'Boldak': 604,
#  'EDT': 605,
#  'Teshiktosh': 606,
#  'soared': 607,
#  '23rd': 608,
#  'buyouts': 609,
#  'tolerated': 610,
#  'Albania': 611,
#  'supplement': 612,
#  'ACLU': 613,
#  'obvious': 614,
#  'US-Central': 615,
#  'tell': 616,
#  'jaws': 617,
#  'NLD': 618,
#  'nationwide': 619,
#  'Number': 620,
#  'then-President': 621,
#  'performing': 622,
#  'restored': 623,
#  'trigger': 624,
#  'consequences': 625,
#  'membership': 626,
#  'underlying': 627,
#  'economic': 628,
#  'Rafah': 629,
#  'amass': 630,
#  'Leasing': 631,
#  'Administrative': 632,
#  'cocked': 633,
#  'Why': 634,
#  'Financial': 635,
#  'Than': 636,
#  'conference': 637,
#  'fabricating': 638,
#  'steer': 639,
#  'Safina': 640,
#  'nullify': 641,
#  'SMART': 642,
#  'efforts': 643,
#  'conversion': 644,
#  'fright': 645,
#  'any': 646,
#  'smashing': 647,
#  'ago': 648,
#  'patrolling': 649,
#  'fused': 650,
#  'Sawyer': 651,
#  'search': 652,
#  'Falcons': 653,
#  'incited': 654,
#  'implications': 655,
#  'provide': 656,
#  'spills': 657,
#  'wars': 658,
#  'Condolezza': 659,
#  'electrocution': 660,
#  'Tetiana': 661,
#  'encouraging': 662,
#  'washed': 663,
#  'European-brokered': 664,
#  'Wam': 665,
#  'rand': 666,
#  'Twelve': 667,
#  'data': 668,
#  'marshy': 669,
#  'interests': 670,
#  'scrapped': 671,
#  'Fort': 672,
#  'exploration': 673,
#  'Harbhajan': 674,
#  'expires': 675,
#  'panels': 676,
#  'Katrina': 677,
#  'guarantee': 678,
#  'defenders': 679,
#  'Beijing-based': 680,
#  'Colom': 681,
#  'member-nations': 682,
#  'self-governing': 683,
#  'disciplined': 684,
#  'Dabas': 685,
#  'Conoco': 686,
#  'cane': 687,
#  'Revolution': 688,
#  'Croat': 689,
#  '45': 690,
#  'Duke': 691,
#  'will': 692,
#  'working': 693,
#  'residing': 694,
#  'Accidents': 695,
#  '1839': 696,
#  'Kamdesh': 697,
#  'martial': 698,
#  'national-level': 699,
#  'billionaire': 700,
#  'Joseph': 701,
#  'gaps': 702,
#  'cancellation': 703,
#  'future': 704,
#  'tourism': 705,
#  'covertly': 706,
#  'Eelam': 707,
#  'cheeks': 708,
#  'Thirty-one-year-old': 709,
#  'Mahsouli': 710,
#  'price': 711,
#  'wedding': 712,
#  'Macedonian-American': 713,
#  'threats': 714,
#  'Alexandria': 715,
#  'BBC': 716,
#  'occupied': 717,
#  'tiny': 718,
#  'Fox': 719,
#  'Kurdistan': 720,
#  'abuses': 721,
#  '1,170': 722,
#  'Vines': 723,
#  'modestly': 724,
#  'Noor': 725,
#  'directive': 726,
#  'non-governmental': 727,
#  'meant': 728,
#  'Sarah': 729,
#  'band': 730,
#  'Maddalena': 731,
#  'headline': 732,
#  'Smaller': 733,
#  'Mahmud': 734,
#  'peg': 735,
#  'Beatrice': 736,
#  'Palma': 737,
#  'Sangin': 738,
#  'peninsula': 739,
#  'sheriff': 740,
#  'filmmaker': 741,
#  '1498': 742,
#  'rates': 743,
#  're-vote': 744,
#  'state-funded': 745,
#  'co-educational': 746,
#  'Caribbean': 747,
#  'French-Colombian': 748,
#  '1.1': 749,
#  'arisen': 750,
#  'human': 751,
#  'ships': 752,
#  'Brazil': 753,
#  'Hiroyuki': 754,
#  'phoenixes': 755,
#  '125': 756,
#  'Gurage': 757,
#  'must': 758,
#  'rendered': 759,
#  'truncated': 760,
#  'accession': 761,
#  'Enlargement': 762,
#  'U.N.': 763,
#  'Qais': 764,
#  'observing': 765,
#  'Velvet': 766,
#  'consented': 767,
#  'Zaken': 768,
#  'Citroën': 769,
#  'Defectors': 770,
#  'toys': 771,
#  'escorted': 772,
#  'Haradinaj': 773,
#  'red-shirts': 774,
#  'Separately': 775,
#  '39': 776,
#  '1,55,000': 777,
#  'leaders': 778,
#  'Ritchie': 779,
#  'Law': 780,
#  'ingratitude': 781,
#  'British-based': 782,
#  'Cavaco': 783,
#  'praying': 784,
#  'privatized': 785,
#  'basket': 786,
#  'apartment': 787,
#  'lawyer-activist': 788,
#  'parents': 789,
#  'Hausa': 790,
#  'universally': 791,
#  'Silvan': 792,
#  'Seville': 793,
#  'win': 794,
#  'Center': 795,
#  'Pascal': 796,
#  'innocence': 797,
#  'paintings': 798,
#  'consisting': 799,
#  'nationalists': 800,
#  'riding': 801,
#  'Kathmandu': 802,
#  'Himalayas': 803,
#  'Jehan': 804,
#  'voices': 805,
#  'total': 806,
#  'economist': 807,
#  'trial': 808,
#  'decreed': 809,
#  'found': 810,
#  'slowed': 811,
#  'hanged': 812,
#  '\x97': 813,
#  'plantation': 814,
#  'apparel': 815,
#  'Shanksville': 816,
#  'Chernikhov': 817,
#  'shake': 818,
#  'five-decade': 819,
#  'neighborhood': 820,
#  'Oxford': 821,
#  'causing': 822,
#  'characterized': 823,
#  'reconciliation': 824,
#  'Nicaragua': 825,
#  'Texmelucan': 826,
#  'Bajur': 827,
#  'patent': 828,
#  'star-studded': 829,
#  'consultation': 830,
#  'Doctors': 831,
#  'pictures': 832,
#  'al-Hariri': 833,
#  'disparity': 834,
#  'proposal': 835,
#  'rocket-propelled': 836,
#  'Investors': 837,
#  'Hamza': 838,
#  'foliage': 839,
#  'Guadalupe': 840,
#  'firearms': 841,
#  'Disasters': 842,
#  'poisoning': 843,
#  'largely': 844,
#  'legalizing': 845,
#  'moments': 846,
#  'trillions': 847,
#  'idleness': 848,
#  'ranges': 849,
#  'rigorous': 850,
#  'radical': 851,
#  'matters': 852,
#  'ribbon': 853,
#  'test-fired': 854,
#  'factories': 855,
#  'seem': 856,
#  'Jawed': 857,
#  'slightly': 858,
#  'Trade': 859,
#  'maltreated': 860,
#  'non-Jews': 861,
#  'Prague': 862,
#  'fertile': 863,
#  'Lage': 864,
#  'Providencia': 865,
#  'indulging': 866,
#  'Peineta': 867,
#  'kilted': 868,
#  'interpreting': 869,
#  'costly': 870,
#  'Namibia': 871,
#  'large-scale': 872,
#  'Kasuri': 873,
#  'Burton': 874,
#  'spying': 875,
#  'Chung': 876,
#  'Hit': 877,
#  'abductors': 878,
#  'regain': 879,
#  '[': 880,
#  '300': 881,
#  'retribution': 882,
#  'Khalis': 883,
#  'dividend': 884,
#  'laughing': 885,
#  'Naked': 886,
#  'Team': 887,
#  'Substantial': 888,
#  'create': 889,
#  'exhumed': 890,
#  'testified': 891,
#  'orderly': 892,
#  'U.S.-educated': 893,
#  'Gbagbo': 894,
#  'addressed': 895,
#  'Organization': 896,
#  'Ismail': 897,
#  'unreliable': 898,
#  'Facility': 899,
#  'containing': 900,
#  'hitch': 901,
#  'Roosevelt': 902,
#  'Pelosi': 903,
#  'auctioneers': 904,
#  'Rohani': 905,
#  'sealing': 906,
#  'Cowell': 907,
#  'Reich': 908,
#  'date': 909,
#  'Zapatista': 910,
#  'populous': 911,
#  'grids': 912,
#  'Adnan': 913,
#  '\x96': 914,
#  'kinds': 915,
#  'sanction': 916,
#  'Force': 917,
#  'move': 918,
#  'Sambadrome': 919,
#  'gunshot': 920,
#  'villages': 921,
#  'customers': 922,
#  'prosecute': 923,
#  'arriving': 924,
#  'Sevilla': 925,
#  'anti-war': 926,
#  'so': 927,
#  'condolences': 928,
#  'western-style': 929,
#  'calm': 930,
#  'retain': 931,
#  'friendship': 932,
#  'Labor': 933,
#  'fate': 934,
#  'mid-year': 935,
#  '54,000': 936,
#  'temper': 937,
#  'hip': 938,
#  'enforcing': 939,
#  'Crown': 940,
#  'flyway': 941,
#  'Joint': 942,
#  'ambassadors': 943,
#  'Hotspur': 944,
#  'avert': 945,
#  'C': 946,
#  'trying': 947,
#  'Survey': 948,
#  'shutdown': 949,
#  'miracles': 950,
#  '1860s': 951,
#  'Chequers': 952,
#  'Zoellick': 953,
#  '314': 954,
#  'slash': 955,
#  'drain': 956,
#  'litigation': 957,
#  'southwestern': 958,
#  'bordered': 959,
#  'child': 960,
#  'replied': 961,
#  'pro-Hezbollah': 962,
#  'Mubarak': 963,
#  'auto': 964,
#  'madrassas': 965,
#  'boost': 966,
#  'ranging': 967,
#  'Pakistani-controlled': 968,
#  'tons': 969,
#  'highways': 970,
#  'Dushevina': 971,
#  'Plachkov': 972,
#  'honesty': 973,
#  'Zvornik': 974,
#  'focal': 975,
#  'p.m.': 976,
#  'hammered': 977,
#  'Duval': 978,
#  'justice': 979,
#  '1970': 980,
#  'rentals': 981,
#  'scoring': 982,
#  'Enriched': 983,
#  'Cindy': 984,
#  'profiled': 985,
#  'KNU': 986,
#  'Federico': 987,
#  'stores': 988,
#  'Jaafari': 989,
#  'configured': 990,
#  '2,711': 991,
#  'reversing': 992,
#  'wetlands': 993,
#  'a': 994,
#  'beasts': 995,
#  'Physician': 996,
#  'corporation': 997,
#  'H.W.': 998,
#  'wrong': 999,
#  ...}

# %%
tag_2_indx
# Out:
# {'<PAD>': 0,
#  'I-tim': 1,
#  'I-geo': 2,
#  'I-per': 3,
#  'I-nat': 4,
#  'B-per': 5,
#  'I-eve': 6,
#  'O': 7,
#  'B-org': 8,
#  'B-geo': 9,
#  'B-tim': 10,
#  'B-gpe': 11,
#  'I-org': 12,
#  'I-gpe': 13,
#  'B-eve': 14,
#  'B-art': 15,
#  'B-nat': 16,
#  'I-art': 17}

# %%
def batch_generator(data,tag,batchsize,shuffle=True,allow_smaller_lastbatch=True):
    N=len(data)
    if shuffle==True:
        order=np.random.permutation(N)
    else:
        order=np.arange(N)
        
    n_batches=N//batchsize
    if allow_smaller_lastbatch and (N%batchsize):
        n_batches+=1
        
    for k in range(n_batches):
        batchstart=k*batchsize
        batchend=min(batchstart+batchsize,N)
        
        currentbatchsize=batchend-batchstart
        
        x_list=[]
        y_list=[]
        
        max_len_token=0
        
        for idx in order[batchstart:batchend]:
            x_list.append([tok_2_indx[i] for i in data[idx]])
            y_list.append([tag_2_indx[i] for i in tag[idx]])
            
            max_len_token=max(max_len_token,len(data[idx]))
        
        x=np.ones([currentbatchsize,max_len_token],dtype=np.int32)*tok_2_indx['<PAD>']
        y=np.ones([currentbatchsize,max_len_token],dtype=np.int32)*tag_2_indx['<PAD>']
        
        lengths=np.zeros(currentbatchsize,dtype=np.int32)
        
        for n in range(currentbatchsize):
            len1=len(x_list[n])
            x[n,:len1]=x_list[n]
            y[n,:len1]=y_list[n]
            
            lengths[n]=len1
        
        yield x,y,lengths

# %%
x=tf.placeholder(dtype=tf.int32,shape=[None,None])
y=tf.placeholder(dtype=tf.int32,shape=[None,None])
lengths=tf.placeholder(dtype=tf.int32,shape=[None])
drpout=tf.placeholder(dtype=tf.float32,shape=[])
lr=tf.placeholder(dtype=tf.float32,shape=[])

# %%
enc_var=tf.Variable(tf.random_normal(shape=[len(tok_2_indx),32]),dtype=tf.float32)
encod_emb=tf.nn.embedding_lookup(enc_var,x)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
forward_cell=tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(200),input_keep_prob=drpout,output_keep_prob=drpout)
backward_cell=tf.nn.rnn_cell.DropoutWrapper(tf.nn.rnn_cell.LSTMCell(200),input_keep_prob=drpout,output_keep_prob=drpout)
# Out:
# WARNING:tensorflow:From <ipython-input-34-9f2cff1552ea>:1: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.

# %%
output,laststate=tf.nn.bidirectional_dynamic_rnn(forward_cell,backward_cell,encod_emb,dtype=tf.float32,sequence_length=lengths)
# Out:
# WARNING:tensorflow:From <ipython-input-35-492cc0916895>:1: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
output1=tf.concat([output[0],output[1]],axis=2)

# %%
output1.get_shape
# Out:
# <bound method Tensor.get_shape of <tf.Tensor 'concat:0' shape=(?, ?, 400) dtype=float32>>

# %%
logits=tf.layers.dense(output1,len(tag_2_indx),activation=None)
# Out:
# WARNING:tensorflow:From <ipython-input-38-8c0ad4682e86>:1: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.

# %%
pred_softmax=tf.nn.softmax(logits,axis=-1)
pred=tf.argmax(pred_softmax,axis=-1)

# %%
ytruth=tf.one_hot(y,len(tag_2_indx))
loss=tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels=ytruth)
# Out:
# WARNING:tensorflow:From <ipython-input-40-f3a5337cc220>:2: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
mask=tf.cast(tf.not_equal(x,tok_2_indx['<PAD>']),tf.float32)

# %%
# very important technique

# %%
loss1=tf.reduce_mean(tf.multiply(loss,mask))

# %%
optimizer=tf.train.AdamOptimizer(learning_rate=lr)
grads_vars=optimizer.compute_gradients(loss1)

# %%
clip_norm=tf.cast(1.0,tf.float32)
grads_vars1=[(tf.clip_by_norm(grad,1.0),var) for grad,var in grads_vars]

# %%
train_op=optimizer.apply_gradients(grads_vars1)

# %%
batchsize=32
epochs=4
lr1=0.006
lr_decay=2**(0.5)
drp=0.8

# %%
sess=tf.Session()
sess.run(tf.global_variables_initializer())

# %%
from tqdm import tqdm

# %%
for epoch in tqdm(range(epochs)):
    count=0
    for xbatch,ybatch,lengths1 in batch_generator(data,tag,batchsize):
        feeddict={x:xbatch,y:ybatch,lengths:lengths1,drpout:drp,lr:lr1}
        _,tloss=sess.run([train_op,loss1],feed_dict=feeddict)
        if (count%50)==0:
            print("count:-",count ," training loss:-",tloss)
        count+=1
    lr1=lr1/(lr_decay)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# count:- 0  training loss:- 1.55556
# count:- 50  training loss:- 0.37945902
# count:- 100  training loss:- 0.31752196
# count:- 150  training loss:- 0.17081818
# count:- 200  training loss:- 0.17584214
# count:- 250  training loss:- 0.1552684
# count:- 300  training loss:- 0.17455608
# count:- 350  training loss:- 0.16225845
# count:- 400  training loss:- 0.099839866
# count:- 450  training loss:- 0.10618548
# count:- 500  training loss:- 0.13133083
# count:- 550  training loss:- 0.0982747
# count:- 600  training loss:- 0.11152212
#  25%|██▌       | 1/4 [01:13<03:41, 73.85s/it]
# count:- 0  training loss:- 0.12571864
# count:- 50  training loss:- 0.10016323
# count:- 100  training loss:- 0.087152556
# count:- 150  training loss:- 0.09487213
# count:- 200  training loss:- 0.08309641
# count:- 250  training loss:- 0.06852732
# count:- 300  training loss:- 0.05986155
# count:- 350  training loss:- 0.08424508
# count:- 400  training loss:- 0.050244156
# count:- 450  training loss:- 0.10526132
# count:- 500  training loss:- 0.09581217
# count:- 550  training loss:- 0.044506274
# count:- 600  training loss:- 0.092876926
#  50%|█████     | 2/4 [02:25<02:26, 73.19s/it]
# count:- 0  training loss:- 0.07017625
# count:- 50  training loss:- 0.06665926
# count:- 100  training loss:- 0.04911716
# count:- 150  training loss:- 0.10768489
# count:- 200  training loss:- 0.049657565
# count:- 250  training loss:- 0.0298312
# count:- 300  training loss:- 0.08335357
# count:- 350  training loss:- 0.04230746
# count:- 400  training loss:- 0.06295563
# count:- 450  training loss:- 0.07834545
# count:- 500  training loss:- 0.038693484
# count:- 550  training loss:- 0.04951909
# count:- 600  training loss:- 0.04657236
#  75%|███████▌  | 3/4 [03:36<01:12, 72.55s/it]
# count:- 0  training loss:- 0.04085439
# count:- 50  training loss:- 0.026922317
# count:- 100  training loss:- 0.04426102
# count:- 150  training loss:- 0.048350465
# count:- 200  training loss:- 0.055296347
# count:- 250  training loss:- 0.043906964
# count:- 300  training loss:- 0.045985863
# count:- 350  training loss:- 0.043728583
# count:- 400  training loss:- 0.045729764
# count:- 450  training loss:- 0.06094584
# count:- 500  training loss:- 0.037540335
# count:- 550  training loss:- 0.03972512
# count:- 600  training loss:- 0.03751281
# 100%|██████████| 4/4 [04:46<00:00, 71.85s/it]

# %%
xtrain=[[tok_2_indx[i] for i in sent] for sent in data]

# %%
ytrain=[[tag_2_indx[i] for i in tagsent] for tagsent in tag]

# %%
len1=[len(sent) for sent in data]

# %%
maxlen=max(len1)

# %%
maxlen
# Out:
# 70

# %%
padarray=np.ones([20000,maxlen])*tok_2_indx['<PAD>']

# %%
paddtokarray=np.ones([20000,maxlen])*tag_2_indx['<PAD>']

# %%
for i in range(20000):
    padarray[i,:len(xtrain[i])]=xtrain[i]
    paddtokarray[i,:len(ytrain[i])]=ytrain[i]

# %%
feeddict={x:padarray,y:paddtokarray,lengths:len1,drpout:1}

# %%
prediction=sess.run([pred],feed_dict=feeddict)

# %%
ind2tag=dict([(v,k) for k,v in tag_2_indx.items()])

# %%
" ".join([ind2tag[i] for i in prediction[0][8][:len1[8]]])
# Out:
# 'B-geo O O O O O O O O O O B-geo O O'

# %%
[ind2tag[i] for i in prediction[0][8][:len1[8]]]
# Out:
# ['B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O']

# %%
tag[8]
# Out:
# ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O']

# %%
f1_score([ind2tag[i] for i in prediction[0][8][:len1[8]]],tag[8],average='macro')
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# 0.5555555555555555

# %%
yactual=[]
ypred=[]
for i in range(20000):
    yactual+=tag[i]
    ypred+=[indx_2_tag[j] for j in prediction[0][i][:len1[i]]]

# %%
len(yactual)
# Out:
# 418914

# %%
len(ypred)
# Out:
# 418914

# %%
f1score=f1_score(ypred,yactual,average='macro')

# %%
f1score
# Out:
# 0.8746991365114806

# %%
prediction[0].shape
# Out:
# (20000, 70)
